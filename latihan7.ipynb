# %%
from matplotlib import pyplot as plt
import cv2

angka = cv2.imread('15.png')
angka = cv2.cvtColor(angka, cv2.COLOR_BGR2RGB)

bilangan = cv2.imread('100.png')
bilangan = cv2.cvtColor(bilangan, cv2.COLOR_BGR2RGB) 
plt.subplot(121),plt.imshow(angka), plt.title('Angka')
plt.subplot(122),plt.imshow(bilangan), plt.title('Susunan Bilangan')
plt.show()

# %%
import cv2
import numpy as np

img_rgb = cv2.imread('100.png')
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

template = cv2.imread('15.png',0)

w, h = template.shape[::-1]

res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)

threshold = 0.1
loc = np.where(res >= threshold)

lspoint=[]
lspoint2=[]
count = 0 
for pt in zip(*loc[::-1]):

    if pt[0] not in lspoint and pt[1] not in lspoint2:
     cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
    for i in range(((pt[0])-9), ((pt[0])+9),1):

        lspoint.append(i)
    for k in range(((pt[1])-9), ((pt[1])+9),1):

        lspoint2.append(k)
        count+=1 
    else:
        continue
print ("Jumlah objek ditemukan ", count)
cv2.imshow("bilangan", img_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Jumlah objek ditemukan  133326
